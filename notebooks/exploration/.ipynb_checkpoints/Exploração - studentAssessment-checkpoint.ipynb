# %% [markdown]
# # Exploração - studentAssessment
#
# Esse notebook tem como objetivo realizar uma analise exploratória da tabela *studentAssessment* que é uma das mais importantes para entender o engajamento do aluno dentro do curso.

# %%
# !pip install -qqq pandas_profiling

import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
from missingno import matrix

mpl.rcParams['figure.dpi'] = 200
sns.set_style("darkgrid")

# %%
arquivos = glob.glob("../../data/raw/*.csv")
arquivos
# Out:
# ['../data/studentAssessment.csv',
#  '../data/studentInfo.csv',
#  '../data/studentVle.csv',
#  '../data/courses.csv',
#  '../data/vle.csv',
#  '../data/studentRegistration.csv',
#  '../data/assessments.csv']

# %%
data = {
    a.split('/')[-1][:-4]: pd.read_csv(a)
    for a in arquivos
}
data.keys()
# Out:
# dict_keys(['studentAssessment', 'studentInfo', 'studentVle', 'courses', 'vle', 'studentRegistration', 'assessments'])

# %% [markdown]
# ## Modelo dos dados
#
# ![](../../images/model.png)
#
# ### Tabela *studentAssessment*

# %%
data['studentAssessment']
# Out:
#         id_assessment  id_student  date_submitted  is_banked  score
# 0                1752       11391              18          0   78.0
# 1                1752       28400              22          0   70.0
# 2                1752       31604              17          0   72.0
# 3                1752       32885              26          0   69.0
# 4                1752       38053              19          0   79.0
# ...               ...         ...             ...        ...    ...
# 173907          37443      527538             227          0   60.0
# 173908          37443      534672             229          0  100.0
# 173909          37443      546286             215          0   80.0
# 173910          37443      546724             230          0  100.0
# 173911          37443      558486             224          0   80.0
#
# [173912 rows x 5 columns]

# %% [markdown]
# ### Analise de valores faltantes
#
# São observados valores faltantes na coluna Score.

# %%
matrix(data['studentAssessment']);

# %%
data['studentAssessment'].describe()
# Out:
#        id_assessment    id_student  date_submitted      is_banked  \
# count  173912.000000  1.739120e+05   173912.000000  173912.000000
# mean    26553.803556  7.051507e+05      116.032942       0.010977
# std      8829.784254  5.523952e+05       71.484148       0.104194
# min      1752.000000  6.516000e+03      -11.000000       0.000000
# 25%     15022.000000  5.044290e+05       51.000000       0.000000
# 50%     25359.000000  5.852080e+05      116.000000       0.000000
# 75%     34883.000000  6.344980e+05      173.000000       0.000000
# max     37443.000000  2.698588e+06      608.000000       1.000000
#
#                score
# count  173739.000000
# mean       75.799573
# std        18.798107
# min         0.000000
# 25%        65.000000
# 50%        80.000000
# 75%        90.000000
# max       100.000000

# %% [markdown]
# ## Entradas individuais
#
# Os campos *"code_module", "code_presentation", "id_student", "id_site", "date"* não possuem apenas uma entrada por combinação na tabela, ou seja, não formam uma chave primária composta. Isso implica que interações feitas pelo mesmo estudante, que está no mesmo modulo de uma mesma oferta, a um mesmo material, no mesmo dia, poderá gerar mais de uma linha caso o estudante entre duas vezes no mesmo material em horarios diferentes.
#
# Para cruzar esses dados com a tabela *studentInfo* precisaremos utilizar os seguintes campos *"code_module", "code_presentation", "id_student"*. Para cada entrada da tabela *studentInfo* podem haver varias linhas na tabela *studentVle* contendo as varias interações que o estudante teve ao longo do curso.

# %%
contagem = data['studentVle'].groupby(["code_module", "code_presentation", "id_student", "id_site", "date"]).count().sum_click
plt.figure(figsize=(3, 2))
contagem.hist(bins=20);

# %% [markdown]
# ### Nota
#
# As notas possuem uma distribuição interessante. A maior parte do peso se encontra em notas acima de 50.
# Vemos também picos na distribuição em notas que podem ser consideradas como "decisivas", por exemplo, há um pico proximo do 40 (corte para aprovação). Outros picos são observados em 60, 80, que talvez ocorram devido a pontos de corte de conceito. Os picos em 0 e 100, já esperados se devem à saturação no valor das notas (um aluno independente do quao "afiado" no conteúdo esteja, jamais poderá tirar mais que 100, o exemplo oposto vale para a nota 0).

# %%
days = data['studentAssessment'].score
plt.figure(figsize=(3, 2))
days.plot.hist(bins=50)
plt.vlines([40, 60, 80, 100], ymin=0, ymax=25000, linestyles='dashdot', linewidths=0.8)
plt.ylim([-10, 25000])
plt.xlabel("Score");

# %% [markdown]
# ### Is Banked
#
# Vemos um volume relativamente pequeno de aproveitamento de avaliações anteriores, cerca de ~1%

# %%
disability = data['studentAssessment'].is_banked.map({0: 'Atual', 1: 'Aproveitado de ofertas anteriores'}).value_counts()
plt.figure(figsize=(3, 2))
disability.plot.pie(autopct='%1.1f%%')
plt.ylabel("");

# %% [markdown]
# ## Profiling automatizado
#
# Executando profiling automatizado para verificar algum outro detalhe que possa ter passado batido.

# %%
from pandas_profiling import ProfileReport

ProfileReport(data['studentAssessment'])
# Out:
# ...
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.9.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2020-11-28 18:19:31.834044&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...
