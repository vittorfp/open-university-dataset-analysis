# %% [markdown]
# # Extração de caracteristicas - studentInfo
#
# Esse notebook tem como objetivo realizar uma analise exploratória da tabela *studentInfo* que é uma das mais importantes para entender o engajamento do aluno dentro do curso.

# %%
# !pip install -qqq pandas_profiling

import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
from missingno import matrix

mpl.rcParams['figure.dpi'] = 200
sns.set_style("darkgrid")

# %%
arquivos = glob.glob("../../data/raw/*.csv")
arquivos
# Out:
# ['../../data/raw/studentAssessment.csv',
#  '../../data/raw/studentInfo.csv',
#  '../../data/raw/studentVle.csv',
#  '../../data/raw/courses.csv',
#  '../../data/raw/vle.csv',
#  '../../data/raw/studentRegistration.csv',
#  '../../data/raw/assessments.csv']

# %%
data = {
    a.split('/')[-1][:-4]: pd.read_csv(a)
    for a in arquivos
}
data.keys()
# Out:
# dict_keys(['studentAssessment', 'studentInfo', 'studentVle', 'courses', 'vle', 'studentRegistration', 'assessments'])

# %% [markdown]
# ## Modelo dos dados
#
# ![](../../images/model.png)
#
# ### Tabela *studentInfo*

# %%
data['studentInfo']
# Out:
#       code_module code_presentation  id_student gender                region  \
# 0             AAA             2013J       11391      M   East Anglian Region
# 1             AAA             2013J       28400      F              Scotland
# 2             AAA             2013J       30268      F  North Western Region
# 3             AAA             2013J       31604      F     South East Region
# 4             AAA             2013J       32885      F  West Midlands Region
# ...           ...               ...         ...    ...                   ...
# 32588         GGG             2014J     2640965      F                 Wales
# 32589         GGG             2014J     2645731      F   East Anglian Region
# 32590         GGG             2014J     2648187      F          South Region
# 32591         GGG             2014J     2679821      F     South East Region
# 32592         GGG             2014J     2684003      F      Yorkshire Region
#
#            highest_education imd_band age_band  num_of_prev_attempts  \
# 0           HE Qualification  90-100%     55<=                     0
# 1           HE Qualification   20-30%    35-55                     0
# 2      A Level or Equivalent   30-40%    35-55                     0
# 3      A Level or Equivalent   50-60%    35-55                     0
# 4         Lower Than A Level   50-60%     0-35                     0
# ...                      ...      ...      ...                   ...
# 32588     Lower Than A Level    10-20     0-35                     0
# 32589     Lower Than A Level   40-50%    35-55                     0
# 32590  A Level or Equivalent   20-30%     0-35                     0
# 32591     Lower Than A Level  90-100%    35-55                     0
# 32592       HE Qualification   50-60%    35-55                     0
#
#        studied_credits disability final_result
# 0                  240          N         Pass
# 1                   60          N         Pass
# 2                   60          Y    Withdrawn
# 3                   60          N         Pass
# 4                   60          N         Pass
# ...                ...        ...          ...
# 32588               30          N         Fail
# 32589               30          N  Distinction
# 32590               30          Y         Pass
# 32591               30          N    Withdrawn
# 32592               30          N  Distinction
#
# [32593 rows x 12 columns]

# %%
studentAssessmentFeatures
# Out:
#                                           totalAssessmentsTaken  meanTMAScore  \
# code_module code_presentation id_student
# AAA         2014J             6516                          5.0     61.800000
# DDD         2013J             8462                          3.0     87.666667
#             2014J             8462                          4.0     86.500000
# AAA         2013J             11391                         5.0     82.000000
# BBB         2013B             23629                         4.0     65.000000
# ...                                                         ...           ...
# AAA         2013J             2698257                       5.0     67.800000
# CCC         2014B             2698535                       4.0     23.000000
# EEE         2013J             2698535                       4.0     54.250000
# BBB         2014J             2698577                       5.0     64.400000
#                               2698588                       5.0     92.400000
#
#                                           meanCMAScore  meanExamScore  \
# code_module code_presentation id_student
# AAA         2014J             6516                 NaN            NaN
# DDD         2013J             8462                 NaN            NaN
#             2014J             8462                 NaN            NaN
# AAA         2013J             11391                NaN            NaN
# BBB         2013B             23629         100.000000            NaN
# ...                                                ...            ...
# AAA         2013J             2698257              NaN            NaN
# CCC         2014B             2698535        24.666667            NaN
# EEE         2013J             2698535              NaN            NaN
# BBB         2014J             2698577              NaN            NaN
#                               2698588              NaN            NaN
#
#                                           submittedLate  totalBanked
# code_module code_presentation id_student
# AAA         2014J             6516                  0.0          0.0
# DDD         2013J             8462                  1.0          0.0
#             2014J             8462                  0.0          4.0
# AAA         2013J             11391                 0.0          0.0
# BBB         2013B             23629                 3.0          0.0
# ...                                                 ...          ...
# AAA         2013J             2698257               2.0          0.0
# CCC         2014B             2698535               3.0          0.0
# EEE         2013J             2698535               1.0          0.0
# BBB         2014J             2698577               0.0          0.0
#                               2698588               1.0          0.0
#
# [25843 rows x 6 columns]

# %%
studentVleFeatures
# Out:
#                                           homepageClicks  \
# code_module code_presentation id_student
# AAA         2013J             11391                  -40
#                               28400                  -80
#                               30268                  -12
#                               31604                 -121
#                               32885                  -68
# ...                                                  ...
# GGG         2014J             2640965                 -5
#                               2645731                -35
#                               2648187                -22
#                               2679821                -13
#                               2684003                -34
#
#                                           homepageInteractions  \
# code_module code_presentation id_student
# AAA         2013J             11391                        138
#                               28400                        324
#                               30268                         59
#                               31604                        432
#                               32885                        204
# ...                                                        ...
# GGG         2014J             2640965                       22
#                               2645731                      167
#                               2648187                       63
#                               2679821                       65
#                               2684003                      120
#
#                                           homepagePreCourseInteractions  \
# code_module code_presentation id_student
# AAA         2013J             11391                                   1
#                               28400                                   7
#                               30268                                   6
#                               31604                                   5
#                               32885                                   8
# ...                                                                 ...
# GGG         2014J             2640965                                 1
#                               2645731                                 0
#                               2648187                                 1
#                               2679821                                 2
#                               2684003                                 8
#
#                                           homepagePreCourseInteractionsClicks  \
# code_module code_presentation id_student
# AAA         2013J             11391                                         7
#                               28400                                        46
#                               30268                                        32
#                               31604                                        30
#                               32885                                        52
# ...                                                                       ...
# GGG         2014J             2640965                                       2
#                               2645731                                       0
#                               2648187                                       6
#                               2679821                                      17
#                               2684003                                      40
#
#                                           forumngClicks  forumngInteractions  \
# code_module code_presentation id_student
# AAA         2013J             11391                 -52                  193
#                               28400                -163                  417
#                               30268                 -30                  126
#                               31604                -197                  634
#                               32885                 -77                  194
# ...                                                 ...                  ...
# GGG         2014J             2640965                 0                    0
#                               2645731               -14                   65
#                               2648187                 0                    0
#                               2679821               -17                  118
#                               2684003               -52                  111
#
#                                           forumngPreCourseInteractions  \
# code_module code_presentation id_student
# AAA         2013J             11391                                  2
#                               28400                                 18
#                               30268                                 10
#                               31604                                  8
#                               32885                                 15
# ...                                                                ...
# GGG         2014J             2640965                                0
#                               2645731                                0
#                               2648187                                0
#                               2679821                                5
#                               2684003                               24
#
#                                           forumngPreCourseInteractionsClicks  \
# code_module code_presentation id_student
# AAA         2013J             11391                                        2
#                               28400                                       73
#                               30268                                       39
#                               31604                                       29
#                               32885                                       73
# ...                                                                      ...
# GGG         2014J             2640965                                      0
#                               2645731                                      0
#                               2648187                                      0
#                               2679821                                     31
#                               2684003                                     53
#
#                                           glossaryClicks  \
# code_module code_presentation id_student
# AAA         2013J             11391                    0
#                               28400                    0
#                               30268                    0
#                               31604                   -1
#                               32885                   -3
# ...                                                  ...
# GGG         2014J             2640965                  0
#                               2645731                 -2
#                               2648187                 -1
#                               2679821                  0
#                               2684003                  0
#
#                                           glossaryInteractions  ...  \
# code_module code_presentation id_student                        ...
# AAA         2013J             11391                          0  ...
#                               28400                          0  ...
#                               30268                          0  ...
#                               31604                          1  ...
#                               32885                          4  ...
# ...                                                        ...  ...
# GGG         2014J             2640965                        0  ...
#                               2645731                        5  ...
#                               2648187                        1  ...
#                               2679821                        0  ...
#                               2684003                        0  ...
#
#                                           folderPreCourseInteractions  \
# code_module code_presentation id_student
# AAA         2013J             11391                                 0
#                               28400                                 0
#                               30268                                 0
#                               31604                                 0
#                               32885                                 0
# ...                                                               ...
# GGG         2014J             2640965                               0
#                               2645731                               0
#                               2648187                               0
#                               2679821                               0
#                               2684003                               0
#
#                                           folderPreCourseInteractionsClicks  \
# code_module code_presentation id_student
# AAA         2013J             11391                                       0
#                               28400                                       0
#                               30268                                       0
#                               31604                                       0
#                               32885                                       0
# ...                                                                     ...
# GGG         2014J             2640965                                     0
#                               2645731                                     0
#                               2648187                                     0
#                               2679821                                     0
#                               2684003                                     0
#
#                                           repeatactivityClicks  \
# code_module code_presentation id_student
# AAA         2013J             11391                          0
#                               28400                          0
#                               30268                          0
#                               31604                          0
#                               32885                          0
# ...                                                        ...
# GGG         2014J             2640965                        0
#                               2645731                        0
#                               2648187                        0
#                               2679821                        0
#                               2684003                        0
#
#                                           repeatactivityInteractions  \
# code_module code_presentation id_student
# AAA         2013J             11391                                0
#                               28400                                0
#                               30268                                0
#                               31604                                0
#                               32885                                0
# ...                                                              ...
# GGG         2014J             2640965                              0
#                               2645731                              0
#                               2648187                              0
#                               2679821                              0
#                               2684003                              0
#
#                                           repeatactivityPreCourseInteractions  \
# code_module code_presentation id_student
# AAA         2013J             11391                                         0
#                               28400                                         0
#                               30268                                         0
#                               31604                                         0
#                               32885                                         0
# ...                                                                       ...
# GGG         2014J             2640965                                       0
#                               2645731                                       0
#                               2648187                                       0
#                               2679821                                       0
#                               2684003                                       0
#
#                                           repeatactivityPreCourseInteractionsClicks  \
# code_module code_presentation id_student
# AAA         2013J             11391                                               0
#                               28400                                               0
#                               30268                                               0
#                               31604                                               0
#                               32885                                               0
# ...                                                                             ...
# GGG         2014J             2640965                                             0
#                               2645731                                             0
#                               2648187                                             0
#                               2679821                                             0
#                               2684003                                             0
#
#                                           htmlactivityClicks  \
# code_module code_presentation id_student
# AAA         2013J             11391                        0
#                               28400                        0
#                               30268                        0
#                               31604                        0
#                               32885                        0
# ...                                                      ...
# GGG         2014J             2640965                      0
#                               2645731                      0
#                               2648187                      0
#                               2679821                      0
#                               2684003                      0
#
#                                           htmlactivityInteractions  \
# code_module code_presentation id_student
# AAA         2013J             11391                              0
#                               28400                              0
#                               30268                              0
#                               31604                              0
#                               32885                              0
# ...                                                            ...
# GGG         2014J             2640965                            0
#                               2645731                            0
#                               2648187                            0
#                               2679821                            0
#                               2684003                            0
#
#                                           htmlactivityPreCourseInteractions  \
# code_module code_presentation id_student
# AAA         2013J             11391                                       0
#                               28400                                       0
#                               30268                                       0
#                               31604                                       0
#                               32885                                       0
# ...                                                                     ...
# GGG         2014J             2640965                                     0
#                               2645731                                     0
#                               2648187                                     0
#                               2679821                                     0
#                               2684003                                     0
#
#                                           htmlactivityPreCourseInteractionsClicks
# code_module code_presentation id_student
# AAA         2013J             11391                                             0
#                               28400                                             0
#                               30268                                             0
#                               31604                                             0
#                               32885                                             0
# ...                                                                           ...
# GGG         2014J             2640965                                           0
#                               2645731                                           0
#                               2648187                                           0
#                               2679821                                           0
#                               2684003                                           0
#
# [29228 rows x 80 columns]

# %%
keys = ["code_module", "code_presentation", "id_student"]

studentAssessmentFeatures = pd.read_csv('../../data/interim/studentAssessmentFeatures.csv').set_index(keys)
studentVleFeatures = pd.read_csv('../../data/interim/studentVleFeatures.csv', sep=';').set_index(keys)


studentModuleData = data['studentInfo']\
    .set_index(keys)\
    .join(studentAssessmentFeatures)\
    .join(studentVleFeatures)

studentModuleData
# Out:
#                                          gender                region  \
# code_module code_presentation id_student
# AAA         2013J             11391           M   East Anglian Region
#                               28400           F              Scotland
#                               30268           F  North Western Region
#                               31604           F     South East Region
#                               32885           F  West Midlands Region
# ...                                         ...                   ...
# GGG         2014J             2640965         F                 Wales
#                               2645731         F   East Anglian Region
#                               2648187         F          South Region
#                               2679821         F     South East Region
#                               2684003         F      Yorkshire Region
#
#                                               highest_education imd_band  \
# code_module code_presentation id_student
# AAA         2013J             11391            HE Qualification  90-100%
#                               28400            HE Qualification   20-30%
#                               30268       A Level or Equivalent   30-40%
#                               31604       A Level or Equivalent   50-60%
#                               32885          Lower Than A Level   50-60%
# ...                                                         ...      ...
# GGG         2014J             2640965        Lower Than A Level    10-20
#                               2645731        Lower Than A Level   40-50%
#                               2648187     A Level or Equivalent   20-30%
#                               2679821        Lower Than A Level  90-100%
#                               2684003          HE Qualification   50-60%
#
#                                          age_band  num_of_prev_attempts  \
# code_module code_presentation id_student
# AAA         2013J             11391          55<=                     0
#                               28400         35-55                     0
#                               30268         35-55                     0
#                               31604         35-55                     0
#                               32885          0-35                     0
# ...                                           ...                   ...
# GGG         2014J             2640965        0-35                     0
#                               2645731       35-55                     0
#                               2648187        0-35                     0
#                               2679821       35-55                     0
#                               2684003       35-55                     0
#
#                                           studied_credits disability  \
# code_module code_presentation id_student
# AAA         2013J             11391                   240          N
#                               28400                    60          N
#                               30268                    60          Y
#                               31604                    60          N
#                               32885                    60          N
# ...                                                   ...        ...
# GGG         2014J             2640965                  30          N
#                               2645731                  30          N
#                               2648187                  30          Y
#                               2679821                  30          N
#                               2684003                  30          N
#
#                                          final_result  totalAssessmentsTaken  \
# code_module code_presentation id_student
# AAA         2013J             11391              Pass                    5.0
#                               28400              Pass                    5.0
#                               30268         Withdrawn                    NaN
#                               31604              Pass                    5.0
#                               32885              Pass                    5.0
# ...                                               ...                    ...
# GGG         2014J             2640965            Fail                    NaN
#                               2645731     Distinction                    9.0
#                               2648187            Pass                    9.0
#                               2679821       Withdrawn                    2.0
#                               2684003     Distinction                    7.0
#
#                                           ...  folderPreCourseInteractions  \
# code_module code_presentation id_student  ...
# AAA         2013J             11391       ...                          0.0
#                               28400       ...                          0.0
#                               30268       ...                          0.0
#                               31604       ...                          0.0
#                               32885       ...                          0.0
# ...                                       ...                          ...
# GGG         2014J             2640965     ...                          0.0
#                               2645731     ...                          0.0
#                               2648187     ...                          0.0
#                               2679821     ...                          0.0
#                               2684003     ...                          0.0
#
#                                           folderPreCourseInteractionsClicks  \
# code_module code_presentation id_student
# AAA         2013J             11391                                     0.0
#                               28400                                     0.0
#                               30268                                     0.0
#                               31604                                     0.0
#                               32885                                     0.0
# ...                                                                     ...
# GGG         2014J             2640965                                   0.0
#                               2645731                                   0.0
#                               2648187                                   0.0
#                               2679821                                   0.0
#                               2684003                                   0.0
#
#                                           repeatactivityClicks  \
# code_module code_presentation id_student
# AAA         2013J             11391                        0.0
#                               28400                        0.0
#                               30268                        0.0
#                               31604                        0.0
#                               32885                        0.0
# ...                                                        ...
# GGG         2014J             2640965                      0.0
#                               2645731                      0.0
#                               2648187                      0.0
#                               2679821                      0.0
#                               2684003                      0.0
#
#                                           repeatactivityInteractions  \
# code_module code_presentation id_student
# AAA         2013J             11391                              0.0
#                               28400                              0.0
#                               30268                              0.0
#                               31604                              0.0
#                               32885                              0.0
# ...                                                              ...
# GGG         2014J             2640965                            0.0
#                               2645731                            0.0
#                               2648187                            0.0
#                               2679821                            0.0
#                               2684003                            0.0
#
#                                           repeatactivityPreCourseInteractions  \
# code_module code_presentation id_student
# AAA         2013J             11391                                       0.0
#                               28400                                       0.0
#                               30268                                       0.0
#                               31604                                       0.0
#                               32885                                       0.0
# ...                                                                       ...
# GGG         2014J             2640965                                     0.0
#                               2645731                                     0.0
#                               2648187                                     0.0
#                               2679821                                     0.0
#                               2684003                                     0.0
#
#                                           repeatactivityPreCourseInteractionsClicks  \
# code_module code_presentation id_student
# AAA         2013J             11391                                             0.0
#                               28400                                             0.0
#                               30268                                             0.0
#                               31604                                             0.0
#                               32885                                             0.0
# ...                                                                             ...
# GGG         2014J             2640965                                           0.0
#                               2645731                                           0.0
#                               2648187                                           0.0
#                               2679821                                           0.0
#                               2684003                                           0.0
#
#                                           htmlactivityClicks  \
# code_module code_presentation id_student
# AAA         2013J             11391                      0.0
#                               28400                      0.0
#                               30268                      0.0
#                               31604                      0.0
#                               32885                      0.0
# ...                                                      ...
# GGG         2014J             2640965                    0.0
#                               2645731                    0.0
#                               2648187                    0.0
#                               2679821                    0.0
#                               2684003                    0.0
#
#                                           htmlactivityInteractions  \
# code_module code_presentation id_student
# AAA         2013J             11391                            0.0
#                               28400                            0.0
#                               30268                            0.0
#                               31604                            0.0
#                               32885                            0.0
# ...                                                            ...
# GGG         2014J             2640965                          0.0
#                               2645731                          0.0
#                               2648187                          0.0
#                               2679821                          0.0
#                               2684003                          0.0
#
#                                           htmlactivityPreCourseInteractions  \
# code_module code_presentation id_student
# AAA         2013J             11391                                     0.0
#                               28400                                     0.0
#                               30268                                     0.0
#                               31604                                     0.0
#                               32885                                     0.0
# ...                                                                     ...
# GGG         2014J             2640965                                   0.0
#                               2645731                                   0.0
#                               2648187                                   0.0
#                               2679821                                   0.0
#                               2684003                                   0.0
#
#                                           htmlactivityPreCourseInteractionsClicks
# code_module code_presentation id_student
# AAA         2013J             11391                                           0.0
#                               28400                                           0.0
#                               30268                                           0.0
#                               31604                                           0.0
#                               32885                                           0.0
# ...                                                                           ...
# GGG         2014J             2640965                                         0.0
#                               2645731                                         0.0
#                               2648187                                         0.0
#                               2679821                                         0.0
#                               2684003                                         0.0
#
# [32593 rows x 95 columns]

# %%
studentModuleData.to_csv('../../data/interim/studentModuleData.csv')

# %%
from pandas_profiling import ProfileReport

ProfileReport(studentModuleData)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Summarize dataset', max=112.0, style=ProgressStyle(descri…

# %%
types = ['homepage', 'forumng', 'glossary', 'oucontent', 'quiz',
       'questionnaire', 'page', 'ouwiki', 'subpage', 'url', 'resource',
       'dualpane', 'ouelluminate', 'dataplus', 'sharedsubpage',
       'oucollaborate', 'externalquiz', 'folder', 'repeatactivity',
       'htmlactivity']

def extract_features(df):
    
    'gender', 'region', 'highest_education', 'imd_band', 'age_band', 'num_of_prev_attempts', 'studied_credits', 'disability', 'final_result'
    features = {}
    
    for act_type in types:
        total = df.query(f"activity_type == '{act_type}'")
        preCourse = total.query("date < 0")

        features[f"{act_type}Clicks"] = len(total),
        features[f"{act_type}Interactions"] = total.sum_click.sum()
        features[f"{act_type}PreCourseInteractions"] = len(preCourse)
        features[f"{act_type}PreCourseInteractionsClicks"] = preCourse.sum_click.sum()
    
    return pd.Series({
        
    })

features = studentModuleData.groupby("id_student").apply(extract_features)
features

# %%
features.to_csv('../../data/interim/studentModuleDataFeatures.csv')
